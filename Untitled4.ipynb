# %% [markdown]
# <a href="https://colab.research.google.com/github/Kumari-Simpi/Airbnb-data-analysis/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %% [markdown]
# so basically it was something nonsense

# %%
r = 5
pi = 1.4
area = 2*pi*r
print(area)
# Out:
# 14.0
